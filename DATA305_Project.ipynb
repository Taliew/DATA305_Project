# %% [markdown]
# ## DATA305 - Project

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load in required packages
import pandas as pd
import os
import random
import numpy as np
from tensorflow.keras import layers
import tensorflow as tf

# %%
# https://link.springer.com/article/10.1007/s10462-025-11148-3
# This article indicates CNNs as being a good choice for APCs, so
# have decided to implement that architecture

# %%
# this random seed will be used for the initial set up (e.g., data split)
random_seed = 0
def set_seeds(seed= random_seed):
  os.environ["PYTHONHASHSEED"] = str(seed)
  random.seed(seed)
  np.random.seed(seed)
  tf.random.set_seed(seed)
  os.environ["TF_DETERMINISTIC_OPS"] = "1"

# %%
set_seeds()

# %%
# load in data
train = pd.read_csv("/content/drive/My Drive/DATA305 Project Data/train.csv")
test =  pd.read_csv("/content/drive/My Drive/DATA305 Project Data/test.csv")

# %% [markdown]
# **Preprocessing**

# %%
train["FASTA_length"] = train["FASTA"].str.len()
train["FASTA_length"].describe()
# min size 10
# max size 50

SEQ_MAX_SIZE = 50

# %%
unique_chars_train = set()
for sequence in train["FASTA"]:
  unique_chars_train.update(sequence)

len(unique_chars_train)

VOCAB_SIZE = 22 # need to add 2 to incl. unknown and padding
# 20 unique amino acids

# %%
from sklearn.model_selection import train_test_split

# validation set of 10% created
X_train, X_val, y_train, y_val = train_test_split(train["FASTA"], train["label"], test_size=0.10, random_state=random_seed)

train_ds = tf.data.Dataset.from_tensor_slices((X_train.values, y_train.values))
valid_ds = tf.data.Dataset.from_tensor_slices((X_val.values, y_val.values))
test_ds = tf.data.Dataset.from_tensor_slices((test["FASTA"].values, test["label"].values))

train_ds = train_ds.batch(24).prefetch(tf.data.AUTOTUNE)
valid_ds = valid_ds.batch(24).prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.batch(24).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# **Modelling**

# %%
#checkpoint and early stopping for feature extraction
checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("model_feature_extract.weights.h5",
save_best_only=True,
save_weights_only=True)
early_stopping_cb = tf.keras.callbacks.EarlyStopping(monitor = "accuracy", patience=3,
restore_best_weights=True)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
results_list = []

seq_vec_layer = tf.keras.layers.TextVectorization(max_tokens = 22,
                                                split = "character",
                                                output_sequence_length = SEQ_MAX_SIZE)

seq_vec_layer.adapt(tf.constant(train["FASTA"].tolist()))

embed_size = 180

for i in range(1,6):
  set_seeds(seed = i)
  inputs = tf.keras.Input(shape=(), dtype=tf.string)
  x = seq_vec_layer(inputs)
  x = layers.Embedding(VOCAB_SIZE, embed_size)(x)
  conv3 = layers.Conv1D(64, 3, activation="relu", padding="same")(x)
  conv5 = layers.Conv1D(64, 5, activation="relu", padding="same")(x)
  conv7 = layers.Conv1D(64, 7, activation="relu", padding="same")(x)
  x = layers.Concatenate()([conv3, conv5, conv7])
  x = layers.GlobalMaxPooling1D()(x)
  x = layers.Dense(64, activation="relu")(x)
  x = layers.Dropout(0.2)(x)
  outputs = layers.Dense(1, activation="sigmoid")(x)
  model = tf.keras.Model(inputs=inputs, outputs=outputs)
  model.compile(loss="binary_crossentropy", optimizer="adam", metrics=[tf.keras.metrics.AUC(curve = "PR", name = "PR_AUC"), tf.keras.metrics.AUC(curve = "ROC", name = "ROC_AUC"),  "accuracy"])
  history = model.fit(train_ds, validation_data=valid_ds, epochs=50, callbacks=[checkpoint_cb, early_stopping_cb])

  # Evaluate the model using test.csv
  results = model.evaluate(test_ds, return_dict=True)
  results_list.append(results)
  print(results)
  tf.keras.backend.clear_session()
# Out:
# Epoch 1/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - PR_AUC: 0.7405 - ROC_AUC: 0.7259 - accuracy: 0.6543 - loss: 0.6147 - val_PR_AUC: 0.8516 - val_ROC_AUC: 0.8387 - val_accuracy: 0.7585 - val_loss: 0.5207
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - PR_AUC: 0.8645 - ROC_AUC: 0.8589 - accuracy: 0.7889 - loss: 0.4685 - val_PR_AUC: 0.8511 - val_ROC_AUC: 0.8396 - val_accuracy: 0.7458 - val_loss: 0.5425
# Epoch 3/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - PR_AUC: 0.8973 - ROC_AUC: 0.8875 - accuracy: 0.8084 - loss: 0.4213 - val_PR_AUC: 0.8580 - val_ROC_AUC: 0.8411 - val_accuracy: 0.7331 - val_loss: 0.5742
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - PR_AUC: 0.9237 - ROC_AUC: 0.9137 - accuracy: 0.8478 - loss: 0.3692 - val_PR_AUC: 0.8572 - val_ROC_AUC: 0.8309 - val_accuracy: 0.7331 - val_loss: 0.6205
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9588 - ROC_AUC: 0.9533 - accuracy: 0.8995 - loss: 0.2772 - val_PR_AUC: 0.8473 - val_ROC_AUC: 0.8188 - val_accuracy: 0.7458 - val_loss: 0.6708
# Epoch 6/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - PR_AUC: 0.9768 - ROC_AUC: 0.9755 - accuracy: 0.9367 - loss: 0.2013 - val_PR_AUC: 0.8399 - val_ROC_AUC: 0.8198 - val_accuracy: 0.7585 - val_loss: 0.7269
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9915 - ROC_AUC: 0.9913 - accuracy: 0.9704 - loss: 0.1179 - val_PR_AUC: 0.8478 - val_ROC_AUC: 0.8109 - val_accuracy: 0.6992 - val_loss: 1.1089
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - PR_AUC: 0.9951 - ROC_AUC: 0.9954 - accuracy: 0.9706 - loss: 0.0954 - val_PR_AUC: 0.8126 - val_ROC_AUC: 0.7525 - val_accuracy: 0.5975 - val_loss: 2.1917
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9758 - ROC_AUC: 0.9731 - accuracy: 0.9001 - loss: 0.2359 - val_PR_AUC: 0.8272 - val_ROC_AUC: 0.7851 - val_accuracy: 0.6907 - val_loss: 1.2997
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9748 - ROC_AUC: 0.9752 - accuracy: 0.9001 - loss: 0.2248 - val_PR_AUC: 0.8212 - val_ROC_AUC: 0.8015 - val_accuracy: 0.7373 - val_loss: 0.9263
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - PR_AUC: 0.7282 - ROC_AUC: 0.6824 - accuracy: 0.6261 - loss: 1.1024
# {'PR_AUC': 0.4574292004108429, 'ROC_AUC': 0.8355369567871094, 'accuracy': 0.8261127471923828, 'loss': 0.5326369404792786}
# Epoch 1/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - PR_AUC: 0.7481 - ROC_AUC: 0.7305 - accuracy: 0.6726 - loss: 0.6113 - val_PR_AUC: 0.8473 - val_ROC_AUC: 0.8405 - val_accuracy: 0.7669 - val_loss: 0.5153
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.8701 - ROC_AUC: 0.8610 - accuracy: 0.7880 - loss: 0.4637 - val_PR_AUC: 0.8449 - val_ROC_AUC: 0.8434 - val_accuracy: 0.7415 - val_loss: 0.5546
# Epoch 3/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - PR_AUC: 0.9009 - ROC_AUC: 0.8909 - accuracy: 0.8251 - loss: 0.4151 - val_PR_AUC: 0.8448 - val_ROC_AUC: 0.8429 - val_accuracy: 0.7288 - val_loss: 0.5675
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9218 - ROC_AUC: 0.9183 - accuracy: 0.8439 - loss: 0.3655 - val_PR_AUC: 0.8411 - val_ROC_AUC: 0.8367 - val_accuracy: 0.7712 - val_loss: 0.5688
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9540 - ROC_AUC: 0.9519 - accuracy: 0.8956 - loss: 0.2840 - val_PR_AUC: 0.8294 - val_ROC_AUC: 0.8204 - val_accuracy: 0.7373 - val_loss: 0.6780
# Epoch 6/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9791 - ROC_AUC: 0.9789 - accuracy: 0.9432 - loss: 0.1919 - val_PR_AUC: 0.8217 - val_ROC_AUC: 0.8162 - val_accuracy: 0.7373 - val_loss: 0.7924
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - PR_AUC: 0.9928 - ROC_AUC: 0.9923 - accuracy: 0.9678 - loss: 0.1211 - val_PR_AUC: 0.8187 - val_ROC_AUC: 0.8055 - val_accuracy: 0.6822 - val_loss: 1.2613
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - PR_AUC: 0.9898 - ROC_AUC: 0.9884 - accuracy: 0.9366 - loss: 0.1467 - val_PR_AUC: 0.8120 - val_ROC_AUC: 0.7771 - val_accuracy: 0.6398 - val_loss: 1.7185
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - PR_AUC: 0.9628 - ROC_AUC: 0.9569 - accuracy: 0.8849 - loss: 0.3048 - val_PR_AUC: 0.8254 - val_ROC_AUC: 0.8052 - val_accuracy: 0.7288 - val_loss: 0.9212
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - PR_AUC: 0.9622 - ROC_AUC: 0.9647 - accuracy: 0.9033 - loss: 0.2678 - val_PR_AUC: 0.8415 - val_ROC_AUC: 0.8129 - val_accuracy: 0.7331 - val_loss: 0.8634
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - PR_AUC: 0.7297 - ROC_AUC: 0.6772 - accuracy: 0.6291 - loss: 1.1457
# {'PR_AUC': 0.4587332308292389, 'ROC_AUC': 0.8285792469978333, 'accuracy': 0.8281899094581604, 'loss': 0.5460943579673767}
# Epoch 1/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - PR_AUC: 0.7425 - ROC_AUC: 0.7287 - accuracy: 0.6729 - loss: 0.6174 - val_PR_AUC: 0.8491 - val_ROC_AUC: 0.8426 - val_accuracy: 0.7669 - val_loss: 0.5046
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - PR_AUC: 0.8625 - ROC_AUC: 0.8581 - accuracy: 0.7884 - loss: 0.4677 - val_PR_AUC: 0.8467 - val_ROC_AUC: 0.8432 - val_accuracy: 0.7627 - val_loss: 0.5265
# Epoch 3/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.8912 - ROC_AUC: 0.8859 - accuracy: 0.8154 - loss: 0.4249 - val_PR_AUC: 0.8483 - val_ROC_AUC: 0.8421 - val_accuracy: 0.7458 - val_loss: 0.5548
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9213 - ROC_AUC: 0.9123 - accuracy: 0.8478 - loss: 0.3746 - val_PR_AUC: 0.8515 - val_ROC_AUC: 0.8351 - val_accuracy: 0.7500 - val_loss: 0.5701
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9516 - ROC_AUC: 0.9481 - accuracy: 0.8829 - loss: 0.2949 - val_PR_AUC: 0.8530 - val_ROC_AUC: 0.8272 - val_accuracy: 0.7627 - val_loss: 0.6013
# Epoch 6/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - PR_AUC: 0.9739 - ROC_AUC: 0.9763 - accuracy: 0.9281 - loss: 0.2095 - val_PR_AUC: 0.8441 - val_ROC_AUC: 0.8124 - val_accuracy: 0.7246 - val_loss: 0.8351
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - PR_AUC: 0.9848 - ROC_AUC: 0.9874 - accuracy: 0.9520 - loss: 0.1542 - val_PR_AUC: 0.8428 - val_ROC_AUC: 0.8070 - val_accuracy: 0.6653 - val_loss: 1.3068
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - PR_AUC: 0.9774 - ROC_AUC: 0.9782 - accuracy: 0.9205 - loss: 0.2026 - val_PR_AUC: 0.8272 - val_ROC_AUC: 0.7922 - val_accuracy: 0.7246 - val_loss: 0.9141
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - PR_AUC: 0.9851 - ROC_AUC: 0.9857 - accuracy: 0.9373 - loss: 0.1554 - val_PR_AUC: 0.8076 - val_ROC_AUC: 0.7931 - val_accuracy: 0.7415 - val_loss: 0.9542
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - PR_AUC: 0.9862 - ROC_AUC: 0.9863 - accuracy: 0.9401 - loss: 0.1484 - val_PR_AUC: 0.7990 - val_ROC_AUC: 0.7934 - val_accuracy: 0.7203 - val_loss: 0.9650
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - PR_AUC: 0.7548 - ROC_AUC: 0.6959 - accuracy: 0.6248 - loss: 1.2026
# {'PR_AUC': 0.5030586123466492, 'ROC_AUC': 0.8510883450508118, 'accuracy': 0.8359050154685974, 'loss': 0.5330011248588562}
# Epoch 1/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - PR_AUC: 0.7599 - ROC_AUC: 0.7395 - accuracy: 0.6686 - loss: 0.6088 - val_PR_AUC: 0.8492 - val_ROC_AUC: 0.8376 - val_accuracy: 0.7500 - val_loss: 0.5330
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.8657 - ROC_AUC: 0.8614 - accuracy: 0.7830 - loss: 0.4685 - val_PR_AUC: 0.8470 - val_ROC_AUC: 0.8343 - val_accuracy: 0.7288 - val_loss: 0.5613
# Epoch 3/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - PR_AUC: 0.8972 - ROC_AUC: 0.8921 - accuracy: 0.8072 - loss: 0.4190 - val_PR_AUC: 0.8509 - val_ROC_AUC: 0.8380 - val_accuracy: 0.7246 - val_loss: 0.5821
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - PR_AUC: 0.9178 - ROC_AUC: 0.9132 - accuracy: 0.8376 - loss: 0.3790 - val_PR_AUC: 0.8555 - val_ROC_AUC: 0.8364 - val_accuracy: 0.7119 - val_loss: 0.6079
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - PR_AUC: 0.9464 - ROC_AUC: 0.9427 - accuracy: 0.8741 - loss: 0.3131 - val_PR_AUC: 0.8485 - val_ROC_AUC: 0.8312 - val_accuracy: 0.7458 - val_loss: 0.6401
# Epoch 6/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9715 - ROC_AUC: 0.9692 - accuracy: 0.9253 - loss: 0.2274 - val_PR_AUC: 0.8417 - val_ROC_AUC: 0.8247 - val_accuracy: 0.7119 - val_loss: 0.7549
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - PR_AUC: 0.9849 - ROC_AUC: 0.9844 - accuracy: 0.9577 - loss: 0.1563 - val_PR_AUC: 0.8407 - val_ROC_AUC: 0.8174 - val_accuracy: 0.7034 - val_loss: 0.9510
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9929 - ROC_AUC: 0.9930 - accuracy: 0.9639 - loss: 0.1147 - val_PR_AUC: 0.8376 - val_ROC_AUC: 0.8194 - val_accuracy: 0.7161 - val_loss: 1.0460
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - PR_AUC: 0.9881 - ROC_AUC: 0.9880 - accuracy: 0.9362 - loss: 0.1481 - val_PR_AUC: 0.8166 - val_ROC_AUC: 0.8098 - val_accuracy: 0.7542 - val_loss: 0.8580
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - PR_AUC: 0.9783 - ROC_AUC: 0.9762 - accuracy: 0.9166 - loss: 0.2096 - val_PR_AUC: 0.8268 - val_ROC_AUC: 0.8186 - val_accuracy: 0.7373 - val_loss: 0.8695
# Epoch 11/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - PR_AUC: 0.9846 - ROC_AUC: 0.9867 - accuracy: 0.9521 - loss: 0.1438 - val_PR_AUC: 0.8129 - val_ROC_AUC: 0.8237 - val_accuracy: 0.7585 - val_loss: 0.8733
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - PR_AUC: 0.7018 - ROC_AUC: 0.6656 - accuracy: 0.6392 - loss: 1.0641
# {'PR_AUC': 0.4304766058921814, 'ROC_AUC': 0.8200766444206238, 'accuracy': 0.8207715153694153, 'loss': 0.5489042401313782}
# Epoch 1/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - PR_AUC: 0.7409 - ROC_AUC: 0.7261 - accuracy: 0.6752 - loss: 0.6142 - val_PR_AUC: 0.8458 - val_ROC_AUC: 0.8401 - val_accuracy: 0.7500 - val_loss: 0.5305
# Epoch 2/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.8605 - ROC_AUC: 0.8535 - accuracy: 0.7782 - loss: 0.4769 - val_PR_AUC: 0.8500 - val_ROC_AUC: 0.8444 - val_accuracy: 0.7500 - val_loss: 0.5476
# Epoch 3/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.8919 - ROC_AUC: 0.8865 - accuracy: 0.7997 - loss: 0.4258 - val_PR_AUC: 0.8503 - val_ROC_AUC: 0.8437 - val_accuracy: 0.7500 - val_loss: 0.5573
# Epoch 4/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - PR_AUC: 0.9194 - ROC_AUC: 0.9135 - accuracy: 0.8459 - loss: 0.3734 - val_PR_AUC: 0.8553 - val_ROC_AUC: 0.8384 - val_accuracy: 0.7542 - val_loss: 0.5866
# Epoch 5/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - PR_AUC: 0.9482 - ROC_AUC: 0.9445 - accuracy: 0.8805 - loss: 0.3031 - val_PR_AUC: 0.8468 - val_ROC_AUC: 0.8254 - val_accuracy: 0.7542 - val_loss: 0.6099
# Epoch 6/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9744 - ROC_AUC: 0.9745 - accuracy: 0.9311 - loss: 0.2065 - val_PR_AUC: 0.8450 - val_ROC_AUC: 0.8231 - val_accuracy: 0.7458 - val_loss: 0.6946
# Epoch 7/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - PR_AUC: 0.9929 - ROC_AUC: 0.9932 - accuracy: 0.9678 - loss: 0.1147 - val_PR_AUC: 0.8348 - val_ROC_AUC: 0.8186 - val_accuracy: 0.6864 - val_loss: 1.0977
# Epoch 8/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - PR_AUC: 0.9955 - ROC_AUC: 0.9963 - accuracy: 0.9753 - loss: 0.0935 - val_PR_AUC: 0.8257 - val_ROC_AUC: 0.8017 - val_accuracy: 0.6610 - val_loss: 1.5904
# Epoch 9/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - PR_AUC: 0.9904 - ROC_AUC: 0.9902 - accuracy: 0.9457 - loss: 0.1338 - val_PR_AUC: 0.8077 - val_ROC_AUC: 0.7645 - val_accuracy: 0.6525 - val_loss: 1.8163
# Epoch 10/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - PR_AUC: 0.9696 - ROC_AUC: 0.9656 - accuracy: 0.8847 - loss: 0.2799 - val_PR_AUC: 0.8143 - val_ROC_AUC: 0.8028 - val_accuracy: 0.7585 - val_loss: 0.8923
# Epoch 11/50
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - PR_AUC: 0.9504 - ROC_AUC: 0.9500 - accuracy: 0.8796 - loss: 0.3221 - val_PR_AUC: 0.8108 - val_ROC_AUC: 0.8051 - val_accuracy: 0.7034 - val_loss: 0.9158
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - PR_AUC: 0.7501 - ROC_AUC: 0.6811 - accuracy: 0.6242 - loss: 1.4051
# {'PR_AUC': 0.4945719242095947, 'ROC_AUC': 0.8311504125595093, 'accuracy': 0.836498498916626, 'loss': 0.6273365020751953}

# %%
results = pd.DataFrame(results_list)
results["Seeds"] = [1,2,3,4,5]
results.set_index("Seeds", inplace=True)
results
# Out:
#          PR_AUC   ROC_AUC  accuracy      loss
# Seeds
# 1      0.457429  0.835537  0.826113  0.532637
# 2      0.458733  0.828579  0.828190  0.546094
# 3      0.503059  0.851088  0.835905  0.533001
# 4      0.430477  0.820077  0.820772  0.548904
# 5      0.494572  0.831150  0.836498  0.627337

# %%
# ROC AUC standard deviation
std_roc_auc = pd.Series(np.std(results["ROC_AUC"])).to_frame()
std_roc_auc.index = ["std ROC AUC"]

# PR AUC standard deviation
std_pr_auc = pd.Series(np.std(results["PR_AUC"])).to_frame()
std_pr_auc.index = ["std PR AUC"]

results = pd.concat([results.mean(), std_roc_auc, std_pr_auc])
results_final = results.drop(["accuracy", "loss"])
results_final = results_final.rename({"PR_AUC" : "mean PR AUC",
                      "ROC_AUC" : "mean ROC AUC"}, axis = 0)
results_final = results_final.rename({0 : "Values"}, axis = 1)
results_final
# Out:
#                 Values
# mean PR AUC   0.468854
# mean ROC AUC  0.833286
# std ROC AUC   0.010229
# std PR AUC    0.026598

# %% [markdown]
# ## Discussion

# %% [markdown]
# **Learnings**
#
# Initially I started with a deep model with three CNN layers, but found that it was not performing too well, likely due to the size of the training set, and reduced it to two layers - which improved performance.
#
# Initially I also had filters increasing with each subsequent CNN layer - in order to capture the simple features in the lower layers and capture more complex features in the upper layers. However I redesigned the architecture after I discovered parallelisation of CNN filters, which was conducted in a similar problem by Ahmed et al. (2021) which could prevent overfitting problems with the approach of multiple layers, whilst still getting the benefits of various kernal sizes according to Martins, C. (2023).
#
# I found that there could be a trade off between PR AUC and ROC AUC with some models doing better in ROC AUC doing poorly in PR AUC and vice-versa. I ensured that there was a balance that resulted in a model that met the requirements as specified by the assignment of:
# - mean PR_AUC >= 0.43
# - mean ROC_AUC >= 0.83
#
# I made a good model which performed to an initial seed. However, what I didn't realise was that clear_session() reset didn't reset the model weights so that the model could be re-trained, so it performed very poorly for my other seeds as it was continuing to train the good model (and overfitting), and therefore performed worse on subsequent seeds / testing sets. I spent a lot of time trying to debug / improve my model to perform on the different seeds, but it was actually a problem with my understanding of clear_session() which was impacting the results of my subsequent testing on different seeds.
#
# I also learned that it's good practice to test the performance of a model across various seeds.
#
# **Difficulties**
#
# I had terrible difficulties with hitting the assignment requirements for AUC ROC and PR AUC, however once I realised the problem with the clear_session function rather than my model, this wasn't a problem anymore.
#
# **What has worked and not worked**
#
# I thought maybe a kernel of 10 would allow the model to detect longer motifs and improve performance however it caused PR_AUC to increase substantially but resulted in AUC_ROC falling below assignment specifications (i.e., PR_AUC and ROC_AUC trade off), so I removed this.
#
# Initially I also tried decreasing filter sizes with depth for the CNN (before I moved to the parallelisation architecture) however this didn't perform well, so went with a static filter size. With the parallisation this was kept as a static / fixed number for each parallelised CNN.
#
# Additionally, for my early stopping I used accuracy rather than ROC AUC or PR AUC as using one of those criterion (ROC AUC vs PR AUC) would cause the other to perform worse, relating to the trade off between the two criteria.
#
# **Future directions**
# - Consulting with a domain expert to consider appropriate transformations or model designs to better capture features.
# - Consider hyperparameter tuning of the model
#
# **References**
#
# Ahmed, S., Muhammod, R., Khan, Z. H., Adilina, S., Sharma, A., Shatabda, S., & Dehzangi, A. (2021). ACP-MHCNN: an accurate multi-headed deep-convolutional neural network to predict anticancer peptides. *Scientific reports*, *11*(1), 23676. https://doi.org/10.1038/s41598-021-02703-3
#
# Martins, C. (2023). *Inception — Understanding Multiple Parallel Convolutional Layers.* Medium. https://cdanielaam.medium.com/inception-understanding-multiple-parallel-convolutional-layers-7be281aab2da
